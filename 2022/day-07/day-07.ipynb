# %%
from collections import defaultdict
from itertools import accumulate

directories: dict[str, int] = defaultdict(int)
path: list[str] = []

with open("input.txt", "r") as file:
    for line in file:
        match line.split():
            case "$", "ls": pass
            case "dir", _: pass
            case "$", "cd", "..": path.pop()
            case "$", "cd", dir: path.append(dir)
            case size, _:
                for p in accumulate(path):
                    directories[p] += int(size)
            case _: pass

print(sum(size for size in directories.values() if size <= 100_000))
# Out:
# 1915606

# %%
print(min(size for size in directories.values() if size >= directories['/'] - (70_000_000 - 30_000_000)))
# Out:
# 5025657
